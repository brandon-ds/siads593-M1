# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
import datetime

# %%
#import copy of FIFA23 - MAIN.csv data set from data folder
fifa23 = pd.read_csv('/workspaces/siads593-M1/data/Copy of FIFA23 - MAIN.csv')

# %%
fifa23.head()
# Out:
#    ID       PlayerName  Rating       Club  Nation NationTop  \
# 0   1             Pelé      98  FUT ICONS  Brazil    Brazil
# 1   2          Ronaldo      96  FUT ICONS  Brazil    Brazil
# 2   3  Zinedine Zidane      96  FUT ICONS  France    France
# 3   4             Pelé      96  FUT ICONS  Brazil    Brazil
# 4   5             Pelé      95  FUT ICONS  Brazil    Brazil
#
#                       Card League LeagueTop  SkillMoves  ...  GK_Kicking  \
# 0     fut23 icon gold rare    ICN       ICN           5  ...         NaN
# 1     fut23 icon gold rare    ICN       ICN           5  ...         NaN
# 2     fut23 icon gold rare    ICN       ICN           5  ...         NaN
# 3  fut23 wc icon gold rare    ICN       ICN           5  ...         NaN
# 4     fut23 icon gold rare    ICN       ICN           5  ...         NaN
#
#   GK_REFLEXES GK_Reflexes GK_SPEED GK_Acceleration  GK_SprintSpeed  \
# 0         NaN         NaN      NaN             NaN             NaN
# 1         NaN         NaN      NaN             NaN             NaN
# 2         NaN         NaN      NaN             NaN             NaN
# 3         NaN         NaN      NaN             NaN             NaN
# 4         NaN         NaN      NaN             NaN             NaN
#
#    GK_POSITIONING  GK_Positioning   isGK  \
# 0             NaN             NaN  False
# 1             NaN             NaN  False
# 2             NaN             NaN  False
# 3             NaN             NaN  False
# 4             NaN             NaN  False
#
#                                 PlayerURL
# 0     https://www.futbin.com/23/player/62
# 1    https://www.futbin.com/23/player/265
# 2    https://www.futbin.com/23/player/303
# 3  https://www.futbin.com/23/player/50235
# 4     https://www.futbin.com/23/player/63
#
# [5 rows x 76 columns]

# %%
# Standardize column names by converting to lowercase and removing leading/trailing whitespaces
standardized_columns = fifa23.columns.str.lower().str.strip()

# Check for duplicate columns after standardization
duplicate_columns = standardized_columns[standardized_columns.duplicated(keep=False)].sort_values()

# Display the duplicate columns, if any
duplicate_columns.unique() if duplicate_columns.any() else "No duplicate columns found after standardization"
# Out:
# Index(['gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes'],
#       dtype='object')

# %%
# Identify the original column names that correspond to the standardized duplicate column names
original_duplicate_columns = [col for col in fifa23.columns if col.lower().strip() in duplicate_columns]

# Group the original duplicate columns by their standardized names for comparison
grouped_duplicate_columns = {}
for standardized_name in duplicate_columns.unique():
    grouped_duplicate_columns[standardized_name] = [col for col in original_duplicate_columns if col.lower().strip() == standardized_name]

# Initialize a dictionary to store the examination results
examination_results = {}

# Examine each set of duplicate columns
for standardized_name, original_names in grouped_duplicate_columns.items():
    # Initialize a dictionary to store results for this set of duplicate columns
    examination_results[standardized_name] = {}
    
    # 1. Compare Value Counts
    value_counts_comparison = pd.DataFrame({name: fifa23[name].value_counts() for name in original_names})
    examination_results[standardized_name]['Value Counts'] = value_counts_comparison
    
    # 2. Check for NaNs
    nan_counts_comparison = pd.DataFrame({name: [fifa23[name].isna().sum()] for name in original_names}, index=['NaN Count'])
    examination_results[standardized_name]['NaN Counts'] = nan_counts_comparison
    
    # 3. Sample Comparison for rows where values differ
    differing_rows = fifa23[original_names].apply(lambda row: len(row.dropna().unique()) > 1, axis=1)
    sample_differing_rows = fifa23.loc[differing_rows, original_names].sample(min(5, differing_rows.sum()), random_state=42)
    examination_results[standardized_name]['Sample Differing Rows'] = sample_differing_rows

# Display the examination results
examination_results
# Out:
# {'gk_diving': {'Value Counts':       GK_DIVING  GK_Diving
#   62.0        104        104
#   64.0        104        104
#   65.0        100        100
#   68.0         93         93
#   67.0         92         92
#   63.0         86         86
#   70.0         85         85
#   66.0         81         81
#   59.0         77         77
#   60.0         74         74
#   69.0         74         74
#   61.0         73         73
#   71.0         73         73
#   72.0         66         66
#   58.0         60         60
#   74.0         52         52
#   73.0         50         50
#   75.0         48         48
#   55.0         47         47
#   78.0         45         45
#   56.0         41         41
#   76.0         39         39
#   57.0         38         38
#   77.0         37         37
#   79.0         35         35
#   80.0         27         27
#   54.0         27         27
#   82.0         26         26
#   51.0         22         22
#   53.0         22         22
#   84.0         21         21
#   81.0         21         21
#   83.0         15         15
#   85.0         15         15
#   52.0         15         15
#   50.0         12         12
#   86.0         12         12
#   87.0         10         10
#   49.0          9          9
#   48.0          8          8
#   88.0          5          5
#   89.0          4          4
#   95.0          2          2
#   92.0          2          2
#   90.0          2          2
#   91.0          2          2
#   93.0          2          2
#   45.0          2          2
#   47.0          1          1
#   42.0          1          1
#   46.0          1          1,
#   'NaN Counts':            GK_DIVING  GK_Diving
#   NaN Count      16159      16159,
#   'Sample Differing Rows': Empty DataFrame
#   Columns: [GK_DIVING, GK_Diving]
#   Index: []},
#  'gk_handling': {'Value Counts':       GK_HANDLING  GK_Handling
#   61.0          116          116
#   64.0          106          106
#   63.0          103          103
#   65.0          102          102
#   62.0           96           96
#   66.0           92           92
#   60.0           90           90
#   59.0           86           86
#   67.0           79           79
#   69.0           78           78
#   56.0           71           71
#   68.0           65           65
#   58.0           63           63
#   70.0           62           62
#   73.0           57           57
#   54.0           57           57
#   57.0           54           54
#   71.0           53           53
#   72.0           53           53
#   53.0           41           41
#   55.0           41           41
#   52.0           37           37
#   74.0           37           37
#   75.0           34           34
#   76.0           31           31
#   78.0           30           30
#   77.0           28           28
#   51.0           24           24
#   50.0           24           24
#   82.0           22           22
#   80.0           20           20
#   79.0           20           20
#   81.0           14           14
#   83.0           12           12
#   49.0           10           10
#   84.0            9            9
#   48.0            9            9
#   85.0            7            7
#   88.0            5            5
#   47.0            5            5
#   45.0            3            3
#   89.0            3            3
#   87.0            3            3
#   86.0            3            3
#   90.0            2            2
#   46.0            1            1
#   44.0            1            1
#   42.0            1            1,
#   'NaN Counts':            GK_HANDLING  GK_Handling
#   NaN Count        16159        16159,
#   'Sample Differing Rows': Empty DataFrame
#   Columns: [GK_HANDLING, GK_Handling]
#   Index: []},
#  'gk_kicking': {'Value Counts':       GK_KICKING  GK_Kicking
#   60.0         111         111
#   64.0         109         109
#   58.0         103         103
#   62.0          99          99
#   65.0          93          93
#   63.0          92          92
#   61.0          89          89
#   59.0          87          87
#   66.0          85          85
#   57.0          83          83
#   67.0          73          73
#   69.0          72          72
#   56.0          65          65
#   68.0          64          64
#   55.0          62          62
#   70.0          58          58
#   53.0          54          54
#   72.0          52          52
#   54.0          52          52
#   73.0          51          51
#   52.0          41          41
#   71.0          37          37
#   75.0          36          36
#   74.0          33          33
#   77.0          32          32
#   51.0          28          28
#   50.0          27          27
#   76.0          23          23
#   78.0          21          21
#   79.0          19          19
#   49.0          13          13
#   82.0          12          12
#   80.0          10          10
#   81.0           9           9
#   85.0           9           9
#   46.0           9           9
#   47.0           7           7
#   83.0           6           6
#   48.0           6           6
#   45.0           5           5
#   87.0           4           4
#   86.0           3           3
#   84.0           3           3
#   88.0           3           3
#   93.0           2           2
#   91.0           2           2
#   42.0           1           1
#   90.0           1           1
#   43.0           1           1
#   40.0           1           1
#   38.0           1           1
#   44.0           1           1,
#   'NaN Counts':            GK_KICKING  GK_Kicking
#   NaN Count       16159       16159,
#   'Sample Differing Rows': Empty DataFrame
#   Columns: [GK_KICKING, GK_Kicking]
#   Index: []},
#  'gk_positioning': {'Value Counts':       GK_POSITIONING  GK_Positioning
#   63.0             105             105
#   65.0             101             101
#   64.0             100             100
#   66.0              83              83
#   58.0              82              82
#   62.0              78              78
#   60.0              74              74
#   68.0              72              72
#   67.0              71              71
#   69.0              70              70
#   61.0              69              69
#   70.0              68              68
#   59.0              65              65
#   73.0              60              60
#   71.0              58              58
#   72.0              53              53
#   56.0              49              49
#   52.0              49              49
#   55.0              46              46
#   57.0              44              44
#   74.0              42              42
#   75.0              42              42
#   78.0              41              41
#   54.0              39              39
#   77.0              37              37
#   51.0              36              36
#   53.0              32              32
#   50.0              31              31
#   76.0              30              30
#   80.0              28              28
#   79.0              27              27
#   81.0              21              21
#   48.0              20              20
#   82.0              17              17
#   49.0              16              16
#   85.0              13              13
#   83.0              13              13
#   84.0              13              13
#   46.0              10              10
#   86.0               9               9
#   47.0               8               8
#   87.0               6               6
#   91.0               5               5
#   89.0               5               5
#   45.0               5               5
#   90.0               5               5
#   44.0               2               2
#   95.0               2               2
#   88.0               2               2
#   92.0               2               2
#   40.0               1               1
#   39.0               1               1
#   42.0               1               1
#   41.0               1               1,
#   'NaN Counts':            GK_POSITIONING  GK_Positioning
#   NaN Count           16159           16159,
#   'Sample Differing Rows': Empty DataFrame
#   Columns: [GK_POSITIONING, GK_Positioning]
#   Index: []},
#  'gk_reflexes': {'Value Counts':       GK_REFLEXES  GK_Reflexes
#   63.0          105          105
#   66.0           98           98
#   64.0           92           92
#   62.0           86           86
#   60.0           85           85
#   67.0           84           84
#   70.0           84           84
#   65.0           81           81
#   71.0           79           79
#   69.0           78           78
#   68.0           73           73
#   72.0           73           73
#   74.0           63           63
#   61.0           60           60
#   75.0           59           59
#   73.0           54           54
#   59.0           53           53
#   76.0           51           51
#   58.0           47           47
#   57.0           42           42
#   55.0           40           40
#   56.0           38           38
#   78.0           37           37
#   77.0           36           36
#   80.0           36           36
#   79.0           31           31
#   82.0           31           31
#   54.0           23           23
#   81.0           22           22
#   83.0           21           21
#   85.0           21           21
#   84.0           18           18
#   51.0           17           17
#   52.0           17           17
#   88.0           17           17
#   53.0           16           16
#   89.0           15           15
#   90.0           12           12
#   86.0           12           12
#   49.0           11           11
#   87.0           11           11
#   50.0           10           10
#   48.0            7            7
#   91.0            4            4
#   47.0            3            3
#   93.0            2            2
#   94.0            1            1
#   92.0            1            1
#   46.0            1            1
#   45.0            1            1
#   96.0            1            1,
#   'NaN Counts':            GK_REFLEXES  GK_Reflexes
#   NaN Count        16159        16159,
#   'Sample Differing Rows': Empty DataFrame
#   Columns: [GK_REFLEXES, GK_Reflexes]
#   Index: []}}

# %%
# Drop the duplicate columns, keeping the first occurrence of each
columns_to_drop = [original_names[1:] for original_names in grouped_duplicate_columns.values()]
columns_to_drop = [col for sublist in columns_to_drop for col in sublist]  # Flatten the list

# Drop the identified columns
df_clean = fifa23.drop(columns=columns_to_drop)

# Display the first few rows of the cleaned DataFrame and its shape
df_clean.head(), df_clean.shape
# Out:
# (   ID       PlayerName  Rating       Club  Nation NationTop  \
#  0   1             Pelé      98  FUT ICONS  Brazil    Brazil
#  1   2          Ronaldo      96  FUT ICONS  Brazil    Brazil
#  2   3  Zinedine Zidane      96  FUT ICONS  France    France
#  3   4             Pelé      96  FUT ICONS  Brazil    Brazil
#  4   5             Pelé      95  FUT ICONS  Brazil    Brazil
#
#                        Card League LeagueTop  SkillMoves  ...  GK_DIVING  \
#  0     fut23 icon gold rare    ICN       ICN           5  ...        NaN
#  1     fut23 icon gold rare    ICN       ICN           5  ...        NaN
#  2     fut23 icon gold rare    ICN       ICN           5  ...        NaN
#  3  fut23 wc icon gold rare    ICN       ICN           5  ...        NaN
#  4     fut23 icon gold rare    ICN       ICN           5  ...        NaN
#
#    GK_HANDLING GK_KICKING GK_REFLEXES GK_SPEED  GK_Acceleration  \
#  0         NaN        NaN         NaN      NaN              NaN
#  1         NaN        NaN         NaN      NaN              NaN
#  2         NaN        NaN         NaN      NaN              NaN
#  3         NaN        NaN         NaN      NaN              NaN
#  4         NaN        NaN         NaN      NaN              NaN
#
#     GK_SprintSpeed  GK_POSITIONING   isGK  \
#  0             NaN             NaN  False
#  1             NaN             NaN  False
#  2             NaN             NaN  False
#  3             NaN             NaN  False
#  4             NaN             NaN  False
#
#                                  PlayerURL
#  0     https://www.futbin.com/23/player/62
#  1    https://www.futbin.com/23/player/265
#  2    https://www.futbin.com/23/player/303
#  3  https://www.futbin.com/23/player/50235
#  4     https://www.futbin.com/23/player/63
#
#  [5 rows x 71 columns],
#  (18119, 71))

# %% [markdown]
# %md
# The missing values in the dataset are primarily concentrated in columns related to goalkeepers:
#
# - GK_DIVING: 16,159 missing values (approximately 89.18%)
# - GK_POSITIONING: 16,159 missing values (approximately 89.18%)
# - GK_SprintSpeed: 16,159 missing values (approximately 89.18%)
# - GK_Acceleration: 16,159 missing values (approximately 89.18%)
# - GK_SPEED: 16,159 missing values (approximately 89.18%)
# - GK_REFLEXES: 16,159 missing values (approximately 89.18%)
# - GK_KICKING: 16,159 missing values (approximately 89.18%)
# - GK_HANDLING: 16,159 missing values (approximately 89.18%)

# %%
# Create two different DataFrames: one for goalkeepers and one for outfield players
df_goalkeepers = df_clean[df_clean['isGK'] == True]
df_outfield = df_clean[df_clean['isGK'] == False]

# Drop columns with null values in the DataFrame for outfield players
df_outfield_clean = df_outfield.dropna(axis=1, how='any')

# Show the shape of the original DataFrame, the goalkeeper DataFrame, and the outfield DataFrame
original_shape = df_clean.shape
goalkeepers_shape = df_goalkeepers.shape
outfield_shape = df_outfield_clean.shape

original_shape, goalkeepers_shape, outfield_shape
# Out:
# ((18119, 71), (1960, 71), (16159, 63))

# %%
df_goalkeepers.describe()
# Out:
#                  ID       Rating   SkillMoves     WeakFoot     HeightCm  \
# count   1960.000000  1960.000000  1960.000000  1960.000000  1960.000000
# mean   10098.451531    66.407653     1.002041     2.539286   189.000000
# std     5473.366809     8.653304     0.063871     0.696001     4.672752
# min       10.000000    46.000000     1.000000     1.000000   170.000000
# 25%     5105.500000    60.000000     1.000000     2.000000   186.000000
# 50%    10467.500000    66.000000     1.000000     3.000000   189.000000
# 75%    15217.750000    72.000000     1.000000     3.000000   192.000000
# max    18119.000000    94.000000     3.000000     5.000000   206.000000
#
#           HeightIn     WeightKg     WeightLb   Popularity     IGS_base  ...  \
# count  1960.000000  1960.000000  1960.000000  1960.000000  1960.000000  ...
# mean     74.421939    81.918878   180.569388    11.998980   365.889796  ...
# std       1.873495     6.368475    14.026275    88.782819    47.919322  ...
# min      67.000000     0.000000     0.000000  -148.000000   252.000000  ...
# 25%      73.000000    78.000000   172.000000     0.000000   333.000000  ...
# 50%      74.000000    82.000000   181.000000     1.000000   363.000000  ...
# 75%      76.000000    86.000000   190.000000     2.000000   398.000000  ...
# max      81.000000   105.000000   231.000000  2866.000000   521.000000  ...
#
#           Strength   Aggression    GK_DIVING  GK_HANDLING   GK_KICKING  \
# count  1960.000000  1960.000000  1960.000000  1960.000000  1960.000000
# mean     60.493367    25.883673    66.871939    64.616837    63.487755
# std      11.001924     7.280898     8.555940     8.179059     8.104212
# min      25.000000    10.000000    42.000000    42.000000    38.000000
# 25%      54.000000    20.000000    61.000000    59.000000    58.000000
# 50%      62.000000    25.000000    66.000000    64.000000    63.000000
# 75%      68.000000    30.000000    72.000000    70.000000    69.000000
# max      85.000000    61.000000    95.000000    90.000000    93.000000
#
#        GK_REFLEXES     GK_SPEED  GK_Acceleration  GK_SprintSpeed  \
# count  1960.000000  1960.000000      1960.000000     1960.000000
# mean     67.886735    37.841327        37.793367       37.920408
# std       8.982907    10.979066        11.518352       11.141752
# min      45.000000    15.000000        14.000000       15.000000
# 25%      62.000000    29.000000        29.000000       29.000000
# 50%      67.000000    38.000000        38.000000       39.000000
# 75%      74.000000    46.000000        46.000000       46.000000
# max      96.000000    86.000000        89.000000       81.000000
#
#        GK_POSITIONING
# count     1960.000000
# mean        65.198469
# std          9.240030
# min         39.000000
# 25%         59.000000
# 50%         65.000000
# 75%         71.000000
# max         95.000000
#
# [8 rows x 55 columns]

# %%
df_outfield_clean.describe()
# Out:
#                  ID        Rating    SkillMoves      WeakFoot      HeightCm  \
# count  16159.000000  16159.000000  16159.000000  16159.000000  16159.000000
# mean    8935.159354     68.400705      2.628752      3.061514    180.859769
# std     5186.526764      8.393300      0.697984      0.683785      6.506361
# min        1.000000     46.000000      2.000000      1.000000    156.000000
# 25%     4464.500000     63.000000      2.000000      3.000000    176.000000
# 50%     8919.000000     67.000000      3.000000      3.000000    181.000000
# 75%    13370.500000     73.000000      3.000000      3.000000    185.000000
# max    18120.000000     98.000000      5.000000      5.000000    206.000000
#
#            HeightIn      WeightKg      WeightLb    Popularity      IGS_base  \
# count  16159.000000  16159.000000  16159.000000  16159.000000  16159.000000
# mean      71.214060     74.547744    164.355777     47.019556    370.749551
# std        2.556365      6.796090     14.973607    278.818373     47.192725
# min       61.000000      0.000000      0.000000  -2648.000000      0.000000
# 25%       69.000000     70.000000    154.000000      0.000000    339.000000
# 50%       71.000000     74.000000    163.000000      1.000000    368.000000
# 75%       73.000000     79.000000    174.000000      4.000000    400.000000
# max       81.000000    102.000000    225.000000   7813.000000    529.000000
#
#        ...  Interceptions  HeadingAccuracy  DefAwareness  StandingTackle  \
# count  ...   16159.000000     16159.000000  16159.000000    16159.000000
# mean   ...      52.570827        58.697011     52.674361       54.250696
# std    ...      18.863194        12.698715     17.793305       18.773807
# min    ...      10.000000        21.000000     10.000000       10.000000
# 25%    ...      38.000000        50.000000     39.000000       39.000000
# 50%    ...      58.000000        58.000000     57.000000       60.000000
# 75%    ...      66.000000        67.000000     66.000000       68.000000
# max    ...      96.000000        99.000000     95.000000       97.000000
#
#        SlidingTackle           PHY       Jumping       Stamina      Strength  \
# count   16159.000000  16159.000000  16159.000000  16159.000000  16159.000000
# mean       51.596881     66.978897     67.524537     69.574107     67.709635
# std        18.802233     10.075989     12.480270     11.818110     12.770188
# min        10.000000     30.000000     29.000000     28.000000     27.000000
# 25%        36.000000     61.000000     60.000000     62.000000     60.000000
# 50%        57.000000     68.000000     69.000000     70.000000     69.000000
# 75%        65.000000     74.000000     76.000000     78.000000     77.000000
# max        99.000000     95.000000     99.000000     99.000000     99.000000
#
#          Aggression
# count  16159.000000
# mean      61.634693
# std       14.014321
# min       20.000000
# 25%       53.000000
# 50%       63.000000
# 75%       72.000000
# max       99.000000
#
# [8 rows x 47 columns]

# %%
# show nique values in FUT ICONS
df_clean['Club'].unique()
# Out:
# array(['FUT ICONS', 'Paris SG', 'FC Barcelona', 'Manchester City',
#        'FC Bayern', 'Liverpool', 'HERO', 'Real Madrid', 'Chelsea',
#        'Manchester Utd', 'Poland', 'Argentina', 'France', 'Belgium',
#        'RB Leipzig', 'Spurs', 'LAFC', 'Milan', 'Salernitana',
#        'Netherlands', 'Portugal', 'Germany', 'Sevilla FC', 'Inter',
#        'Dortmund', 'Atlético de Madrid', 'Ajax', 'Brazil', 'South Korea',
#        'England', 'Senegal', 'Fulham', 'SS Lazio', 'Newcastle Utd',
#        'Uruguay', 'Roma FC', 'Arsenal', 'Villarreal CF', 'Inter Miami CF',
#        'Frankfurt', 'Juventus', 'Costa Rica', 'Croatia', 'Angers SCO',
#        'Leicester City', 'Napoli', 'Leverkusen', 'West Ham', 'PSV',
#        'SL Benfica', 'Real Betis', 'Toronto FC', 'OM', 'Galatasaray',
#        'TSG Hoffenheim', 'Spain', 'Aston Villa', 'Real Sociedad',
#        'Rennes', 'Stade de Reims', 'AS Monaco', 'FC Nantes', 'Fiorentina',
#        'OL', 'Crystal Palace', 'Rayo Vallecano', 'Union Berlin', 'QPR',
#        'RC Lens', 'OGC Nice', 'Sassuolo', 'Bologna', 'Chicago Fire',
#        'Fenerbahçe', 'Serbia', "M'gladbach", 'Werder Bremen',
#        'Athletic Club', 'Columbus Crew SC', 'Wolves', 'Brighton',
#        'Leeds United', 'LOSC', 'Japan', 'RC Celta', 'LA Galaxy',
#        'Brentford', 'VfL Wolfsburg', 'Cádiz CF', 'Girona FC', 'La Spezia',
#        'VfB Stuttgart', 'Sint-Truiden', 'RCD Mallorca', 'Hertha Berlin',
#        'Club Brugge', '1. FSV Mainz 05', 'AFC Bournemouth', 'VfL Bochum',
#        'Sampdoria', 'Getafe CF', 'Real Salt Lake', 'R. Valladolid CF',
#        'Switzerland', 'Torino', 'Qatar', '1. FC Köln', 'Al Hilal',
#        'Nashville SC', 'Düsseldorf', 'Montpellier', 'FC Famalicão',
#        'Atlanta United', 'NEC Nijmegen', 'Atalanta BC', 'SC Braga',
#        'Houston Dynamo', 'Everton', 'UD Almería', 'CA Osasuna', 'Norwich',
#        'SC Freiburg', 'AC Ajaccio', 'FC Lorient', 'Konyaspor',
#        'Feyenoord', 'Hellas Verona', 'Seattle Sounders', 'Boavista FC',
#        'Morocco', 'Denmark', 'Canada', 'Ghana', 'Celtic', 'Austin FC',
#        'FC Porto', 'FC Utrecht', 'Udinese', 'AZ', 'RCD Espanyol',
#        'Sporting CP', 'FC Dallas', 'Watford', 'Kasimpaşa',
#        'Karagümrük SK', 'USA', 'Mexico', 'Cameroon', 'Al Nassr',
#        'Valencia CF', 'Royal Antwerp FC', 'Sunderland', 'FC Groningen',
#        'River Plate', 'Marítimo', 'Empoli', 'New England', 'Burnley',
#        'Millwall', "Nott'm Forest", 'Trabzonspor', 'KRC Genk', 'Wales',
#        'Iran', 'RSC Anderlecht', 'Shanghai SIPG', 'Al Shabab',
#        'Southampton', 'FC Augsburg', 'Başakşehir', 'Colón', 'Daegu FC',
#        'Dynamo Kyiv', 'Slavia Praha', 'LASK', 'Tunisia', 'Ecuador',
#        'Dinamo Zagreb', 'UD Las Palmas', 'Elche CF', 'AC Monza',
#        'Panathinaikos', 'Mamelodi Sundowns', 'Australia', 'Saudi Arabia',
#        'Minnesota United', 'Adana Demirspor', 'Brøndby IF',
#        'Wuhan Three Towns', 'Lecce', 'Strasbourg', 'Beşiktaş',
#        'Boca Juniors', 'Parma', 'Al-Wehda FC', 'Cercle Brugge',
#        'Damac FC', 'Molde FK', 'OH Leuven', 'Stade Brestois 29',
#        'SK Rapid Wien', 'Malmö FF', 'Legia Warszawa', 'Hannover 96',
#        'FC Twente', 'Rangers', 'Antalyaspor', 'Levante UD',
#        'FC København', 'Shakhtar Donetsk', 'Al Ittihad', 'FC Basel 1893',
#        'Nacional', 'Racing Club', 'Granada CF', 'Univ. Craiova',
#        'FC Cincinnati', 'Philadelphia', 'Tigre', 'Derby County',
#        'Zulte Waregem', 'Middlesbrough', 'Fortuna Sittard', 'PAOK',
#        'HNK Hajduk Split', 'Sparta Praha', 'AEK Athens', 'Gil Vicente',
#        'FC Sion', 'Melb. Victory', 'Wuhan Zall', 'Vélez Sarsfield',
#        'R. Sporting', 'R. Oviedo', 'Racing de Santander',
#        'Birmingham City', 'RB Salzburg', 'FC Zürich', 'FC Metz',
#        'FC Schalke 04', 'Estudiantes', 'Sivasspor', 'New York City FC',
#        'Portland Timbers', 'Clermont', 'FC Midtjylland',
#        'Ferencvárosi TC', 'Ettifaq FC', 'Servette FC', 'Shenzhen Kaisa',
#        'Independiente', 'Olimpia', 'Cremonese', 'Viktoria Plzeň',
#        'D. Alavés', 'Uni. Católica', 'KAA Gent', 'BSC Young Boys',
#        'Godoy Cruz', 'Al Ain FC', 'FC Lugano', 'Motherwell', 'Modena',
#        'Central Córdoba', 'Seongnam FC', 'Central Coast',
#        'Raków Częstochowa', 'Rongcheng FC', 'Amiens SC', 'Gaziantep',
#        'Sheffield Utd', 'Blackburn Rovers', 'West Brom', 'AJ Auxerre',
#        'Al Fayha', 'IFK Göteborg', 'Libertad', 'Shandong Luneng',
#        'SM Caen', 'Sporting KC', 'Impact Montréal', 'Changchun Yatai',
#        'Barcelona SC', 'Kaiserslautern', 'Atl. Nacional', 'CS Emelec',
#        'D.C. United', 'Whitecaps FC', 'Adelaide United', 'Melbourne City',
#        'Troyes', 'Al Fateh', 'Talleres', 'Gimnasia', "Newell's",
#        'SJ Earthquakes', 'Orlando Pirates', 'Defensa', 'Huracán',
#        'Colo-Colo', 'Vitesse', 'Al Taawoun', 'Cagliari', 'Cerro Porteño',
#        'MKE Ankaragücü', 'Bordeaux', 'Bielefeld', 'Royale Union SG',
#        'KVC Westerlo', 'Lincoln City', 'Zhejiang Pro', 'UD Ibiza',
#        'Deportivo Cali', 'Pisa', 'Exeter City', 'ATK Mohun Bagan FC',
#        'St. Pats', 'FC St. Gallen', 'Heart of Midlothian', 'Lanús',
#        'Junior', 'Henan Jianye', 'Santa Clara', 'Paços Ferreira',
#        'FC Seoul', 'Genoa', 'SD Eibar', 'Alanyaspor', 'Kayserispor',
#        'CD Leganés', 'V. Guimarães', 'Guangzhou R&F', 'Jeonbuk Hyundai',
#        'Orlando City', 'Suwon Samsung', 'KV Mechelen', 'Aldosivi',
#        'Al Adalah', 'Kaizer Chiefs', 'FK Bodø/Glimt', 'Hamburger SV',
#        'Argentinos Jrs.', 'Preston', 'Sp. Charleroi', 'Hull City',
#        'Charlotte FC', 'Toulouse FC', 'KV Kortrijk', 'Shanghai Shenhua',
#        'Coventry City', 'Casa Pia AC', 'KV Oostende', 'NY Red Bulls',
#        'Peñarol', 'VAFC', 'Paris FC', 'Alianza Lima', 'Deportes Tolima',
#        'Burton Albion', 'Chindia', 'AIK', 'Málaga CF', 'SD Huesca',
#        'Como', 'Western United', 'Everton de Viña del Mar',
#        'Pogoń Szczecin', 'CD Lugo', 'EA Guingamp', 'Shijiazhuang',
#        'SD Ponferradina', 'Bristol City', 'Atlético Tucumán',
#        'IF Elfsborg', 'SV Darmstadt 98', 'Hammarby IF', 'Al Raed',
#        'KAS Eupen', 'FC Luzern', 'Djurgårdens IF', 'Venezia', 'Reading',
#        'Swansea City', 'CD Tenerife', 'Ulsan Hyundai', 'Al Khaleej',
#        'Jeju United', 'Independiente Medellín', 'Unión', '1. FC Nürnberg',
#        'Rosario Central ', 'Benevento', 'Al Batin', 'SK Sturm Graz',
#        'Standard Liège', 'Villarreal CF B', 'Portimonense SC',
#        'FBC Melgar', 'Lech Poznań', 'APOEL Nicosia', 'Abha Club',
#        'Nîmes Olympique', 'LDU Quito', 'ASSE', 'Go Ahead Eagles',
#        'Reggina', 'Giresunspor', 'Club Atlético Platense', 'Banfield',
#        'Cosenza', 'Niort', 'Bari', 'Ascoli', 'Frosinone', 'Rio Ave',
#        'Hatayspor', 'Aarhus AGF', 'Club Atlético Sarmiento (Junin)',
#        'Górnik Zabrze', 'WS Wanderers', 'Sheffield Wed', 'FC Cartagena',
#        'Rosenborg BK', 'Macarthur FC', 'Huddersfield', 'Stoke City',
#        'Pohang Steelers', 'Aalborg BK', 'Sporting Cristal',
#        'Colorado Rapids', 'GD Estoril Praia', 'Palermo', 'Al-Tai',
#        'Greuther Fürth', 'SV Sandhausen', 'Piast Gliwice',
#        'Hansa Rostock', '1. FC Heidenheim', 'San Lorenzo', 'Dijon FCO',
#        'FC Vizela', 'FC St. Pauli', 'Sparta Rotterdam', 'Beijing Guoan',
#        'Karlsruher SC', 'Luton Town', 'Patronato', 'FCSM', 'FCSB',
#        'CFR 1907 Cluj', 'SC Heerenveen', 'Burgos CF',
#        'River Plate Montevideo', 'Unión La Calera', 'Brescia', 'Spal',
#        'Universidad Católica del Ecuador', 'Helsingborgs IF',
#        'SC Paderborn 07', 'Guangzhou', 'Holstein Kiel', 'FK Austria Wien',
#        'R. Zaragoza', 'Perth Glory', 'IFK Norrköping',
#        'Vålerenga Fotball', 'Cardiff City', 'FC Ingolstadt',
#        'Peterborough', 'Viking FK', 'Suwon FC', 'Hibernian', 'FC Arouca',
#        'BK Häcken', 'Silkeborg IF', 'Rotherham Utd', 'Wigan Athletic',
#        'Jahn Regensburg', '1. FC Magdeburg', 'Havre AC', 'Grasshoppers',
#        'Incheon United', 'FC Farul Constanta', 'Blackpool',
#        'Braunschweig', 'Perugia', 'Ternana', 'Südtirol', 'The Strongest',
#        'Hyderabad FC', 'Erzgebirge Aue', 'FC U Craiova 1948',
#        'Lechia Gdańsk', 'Sydney FC', 'Bengaluru FC', 'Brisbane Roar',
#        'FC Annecy', 'Ümraniyespor', 'Cracovia', 'Randers FC',
#        'Dundee United', 'Tianjin TEDA', 'RFC Seraing', 'FC Emmen',
#        'Shamrock Rovers', 'Barracas Central', 'Oxford United',
#        'Albacete Balompié', 'Wilstermann', 'FC Nordsjælland',
#        'Jagiellonia', 'FC Volendam', 'Kalmar FF', 'Wolfsberger AC',
#        'Gangwon FC', 'Aberdeen', 'CD Mirandés', 'Mumbai City FC',
#        'Rodez AF', 'UTA Arad', 'Barnsley', 'Always Ready',
#        'Deportes Antofagasta', 'GD Chaves', 'FC Petrolul', 'Guaireña FC',
#        'Meizhou Hakka', 'Newcastle Jets', 'FC Andorra', 'Barrow',
#        'SC Cambuur', 'VfL Osnabrück', 'Grenoble', 'Portsmouth', 'FC Goa',
#        'SV Waldhof', 'Wycombe', 'Odense BK', 'Ipswich', 'SV Ried',
#        'FC Botoșani', 'Caracas FC', 'Radomiak Radom',
#        'Independiente Petrolero', 'Śląsk Wrocław', 'Well. Phoenix',
#        '1860 München', 'Lillestrøm SK', 'FC Rapid', 'Dynamo Dresden',
#        'HJK Helsinki', 'Oriente Petrolero', 'İstanbulspor',
#        'St. Johnstone', 'Gimcheon Sangmu', 'Sarpsborg 08', 'Ayacucho',
#        'Excelsior', 'MK Dons', 'Jamshedpur FC', 'Aalesunds FK',
#        'RKC Waalwijk', 'TSV Hartberg', 'Chennaiyin FC', 'GIF Sundsvall',
#        'Strømsgodset IF', 'Kerala Blasters FC', 'FSV Zwickau',
#        'WSG Tirol', 'Morecambe', 'Charlton Ath', 'Hallescher FC',
#        'Dep. La Guaira', 'Cheltenham Town', 'Sepsi OSK', 'St. Mirren',
#        'Fleetwood Town', 'Plymouth Argyle', 'Bolton', 'Metropolitanos',
#        'Saarbrücken', 'Zagłębie Lubin', 'Miedź Legnica', 'Dep. Táchira',
#        'Wisła Płock', 'Stade Lavallois', 'Cittadella', 'Odisha FC',
#        'Montevideo Wanderers', '9 de Octubre', 'Quevilly Rouen Métropole',
#        'Dalian Pro', 'FC Argeș', 'MSV Duisburg', 'Shrewsbury',
#        'PGE Stal Mielec', 'SCR Altach', 'Viktoria Köln', 'FC Voluntari',
#        'Accrington', 'SV Elversberg', 'SV Meppen', 'Bradford City',
#        'Kristiansund', 'Degerfors IF', 'SK Austria Klagenfurt',
#        'FC Univ. Cluj', 'Kilmarnock', 'Wrexham AFC', 'Odds BK',
#        'Hebei CFFC', 'Pau FC', 'Viborg FF', 'Bohemian FC', 'Ross County',
#        'SC Bastia', 'SC Austria', 'Warta Poznań', 'Rot-Weiss Essen',
#        'Salford City', 'Colchester', 'Tromsø IL', 'AFC Wimbledon',
#        'Port Vale', 'Forest Green', 'Leyton Orient', 'FK Haugesund',
#        'Mansfield Town', 'IK Sirius', 'Livingston', 'Cambridge Utd',
#        'Northampton', 'Derry City', 'SC Freiburg II', 'SVWW',
#        'Sandefjord', 'Borussia Dortmund II', 'Korona Kielce', 'Lyngby BK',
#        'AC Horsens', 'FC Winterthur', 'FC Hermannstadt', 'IFK Värnamo',
#        'Doncaster', 'Harrogate Town', 'Mjällby AIF ', 'VfB Oldenburg',
#        'Dundalk', 'Widzew Łódź', 'Tranmere Rovers', 'Swindon Town',
#        'Rochdale', 'Crawley Town', 'Bristol Rovers', 'SC Verl',
#        'Stockport', 'Varbergs BoIS', 'Hartlepool United',
#        'HamKam Fotball', 'Sligo Rovers', 'Walsall', 'CS Mioveni',
#        'Carlisle United', 'Gillingham', 'Crewe Alexandra',
#        'Newport County', 'Stevenage', 'SpVgg Bayreuth', 'Sutton United',
#        'FK Jerv', 'Grimsby Town', 'Finn Harps', 'General Caballero (JLM)',
#        'Drogheda United FC', 'Shelbourne', 'SC East Bengal', 'UCD',
#        'NorthEast United FC'], dtype=object)

# %% [markdown]
# ## Numerical colummn analasis
# #### Distribution Analysis
# []. need to carefully id var types and redo

# %%
# Function to plot distribution for numerical columns
def plot_distribution(df, columns, title):
    plt.figure(figsize=(20, 15))
    for i, col in enumerate(columns, 1):
        plt.subplot(4, 4, i)
        sns.histplot(df[col], kde=True, bins=30)
        plt.title(f'Distribution of {col}')
        plt.tight_layout()
    plt.suptitle(title, y=1.02)
    plt.show()

# Select a subset of key numerical columns for distribution analysis
key_goalkeeper_columns = ['Rating', 'HeightCm', 'WeightKg', 'GK_DIVING', 'GK_HANDLING', 'GK_KICKING', 'GK_POSITIONING', 'GK_REFLEXES']
key_outfield_columns = ['Rating', 'HeightCm', 'WeightKg', 'Shooting', 'Passing', 'Dribbling', 'Defending']

# Plot distribution for key numerical columns in goalkeepers DataFrame
plot_distribution(df_goalkeepers, key_goalkeeper_columns, 'Distribution of Key Numerical Columns for Goalkeepers')

# Plot distribution for key numerical columns in outfield players DataFrame
plot_distribution(df_outfield_clean, key_outfield_columns, 'Distribution of Key Numerical Columns for Outfield Players')
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Shooting'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb Cell 13 line 2
#      <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> plot_distribution(df_goalkeepers, key_goalkeeper_columns, 'Distribution of Key Numerical Columns for Goalkeepers')
#      <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> # Plot distribution for key numerical columns in outfield players DataFrame
# ---> <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> plot_distribution(df_outfield_clean, key_outfield_columns, 'Distribution of Key Numerical Columns for Outfield Players')
#
# /workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb Cell 13 line 6
#       <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> for i, col in enumerate(columns, 1):
#       <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     plt.subplot(4, 4, i)
# ----> <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     sns.histplot(df[col], kde=True, bins=30)
#       <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     plt.title(f'Distribution of {col}')
#       <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     plt.tight_layout()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Shooting'

# %% [markdown]
# #### Correlation Analysis

# %%
# Function to plot correlation heatmap for numerical columns
def plot_correlation(df, columns, title):
    correlation_matrix = df[columns].corr()
    plt.figure(figsize=(12, 10))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
    plt.title(title)
    plt.show()

# Plot correlation heatmap for key numerical columns in goalkeepers DataFrame
plot_correlation(df_goalkeepers, key_goalkeeper_columns, 'Correlation Matrix of Key Numerical Columns for Goalkeepers')

# Plot correlation heatmap for key numerical columns in outfield players DataFrame
plot_correlation(df_outfield_clean, key_outfield_columns, 'Correlation Matrix of Key Numerical Columns for Outfield Players')

# %%
from sklearn.ensemble import IsolationForest

# Function to identify outliers using Isolation Forest algorithm
def isolation_forest_outliers(df, columns):
    iso_forest = IsolationForest(contamination=0.05)
    df_subset = df[columns].dropna()
    iso_forest.fit(df_subset)
    outlier_pred = iso_forest.predict(df_subset)
    outlier_indices = df_subset.index[outlier_pred == -1].tolist()
    return outlier_indices

# Identify outliers in goalkeepers DataFrame using Isolation Forest for key numerical columns
goalkeeper_outliers_iso = isolation_forest_outliers(df_goalkeepers, key_goalkeeper_columns)

# Identify outliers in outfield players DataFrame using Isolation Forest for key numerical columns
outfield_outliers_iso = isolation_forest_outliers(df_outfield_clean, key_outfield_columns)

# Count of unique outliers identified by Isolation Forest
goalkeeper_outliers_iso_count = len(set(goalkeeper_outliers_iso))
outfield_outliers_iso_count = len(set(outfield_outliers_iso))

goalkeeper_outliers_iso_count, outfield_outliers_iso_count
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb Cell 16 line 1
#      <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> goalkeeper_outliers_iso = isolation_forest_outliers(df_goalkeepers, key_goalkeeper_columns)
#      <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> # Identify outliers in outfield players DataFrame using Isolation Forest for key numerical columns
# ---> <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> outfield_outliers_iso = isolation_forest_outliers(df_outfield_clean, key_outfield_columns)
#      <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> # Count of unique outliers identified by Isolation Forest
#      <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> goalkeeper_outliers_iso_count = len(set(goalkeeper_outliers_iso))
#
# /workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb Cell 16 line 6
#       <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> def isolation_forest_outliers(df, columns):
#       <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     iso_forest = IsolationForest(contamination=0.05)
# ----> <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     df_subset = df[columns].dropna()
#       <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     iso_forest.fit(df_subset)
#       <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     outlier_pred = iso_forest.predict(df_subset)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:6178, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Shooting', 'Passing', 'Defending'] not in index"

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bscaling-space-invention-496r4vjwxxrh56w/workspaces/siads593-M1/code/notebooks/brandon-eda.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> key_goalkeeper_columns.columns
#
# AttributeError: 'list' object has no attribute 'columns'

# %%
from scipy.stats import ttest_ind

# Conduct a t-test to compare the mean ratings between goalkeepers and outfield players
goalkeeper_ratings = df_goalkeepers['Rating'].dropna()
outfield_ratings = df_outfield_clean['Rating'].dropna()

# Perform the t-test
t_stat, p_value = ttest_ind(goalkeeper_ratings, outfield_ratings)

# Interpret the results
significance_level = 0.05  # 5% significance level
is_significant = p_value < significance_level

t_stat, p_value, is_significant
# Out:
# (-9.894227515824637, 5.0446674765858525e-23, True)

# %% [markdown]
# ## Cat vars

# %%
# Identify all categorical columns in the outfield players DataFrame
outfield_categorical_columns = df_outfield_clean.select_dtypes(include=['object']).columns

# Display the categorical columns
outfield_categorical_columns
# Out:
# Index(['PlayerName', 'Club', 'Nation', 'NationTop', 'Card', 'League',
#        'LeagueTop', 'StrongFoot', 'Position', 'WorkRateAtk', 'WorkRateDef',
#        'BodyType', 'DOB', 'DateAdded', 'PlayerURL'],
#       dtype='object')

# %%
# Select key categorical columns for outfield players DataFrame for more in-depth analysis
key_outfield_categorical_columns = ['Club', 'Nation', 'League', 'StrongFoot', 'Position', 'WorkRateAtk', 'WorkRateDef', 'BodyType']

# Plot category distribution for key categorical columns in outfield players DataFrame
plot_category_distribution(df_outfield_clean, key_outfield_categorical_columns, 'Category Distribution for Outfield Players')
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Redefining the function to plot category distribution for categorical columns
def plot_category_distribution(df, columns, title):
    plt.figure(figsize=(20, 15))
    sns.set(style="whitegrid")
    sns.set_palette("pastel")
    
    for i, col in enumerate(columns, 1):
        plt.subplot(4, 2, i)
        if df[col].nunique() > 10:  # Limit categories for high cardinality columns
            sns.countplot(data=df, y=col, order=df[col].value_counts().iloc[:10].index)
        else:
            sns.countplot(data=df, y=col, order=df[col].value_counts().index)
        plt.title(f'Distribution of {col}')
        plt.tight_layout()
    plt.suptitle(title, y=1.02, fontsize=16)
    plt.show()

# Plot category distribution for key categorical columns in outfield players DataFrame
plot_category_distribution(df_outfield_clean, key_outfield_categorical_columns, 'Category Distribution for Outfield Players')
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
